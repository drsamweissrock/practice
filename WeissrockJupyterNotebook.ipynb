# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **Dr. Sam Weissrock** <br>
# Industrial & Organizational Psychologist

# %% [markdown]
# *I am interested in data science as an extension to my research in the use of language to influence the perception of the consumer. I have applied qualitative frameworks and methodologies and would like to extend to quantitative measurements. My career has been primarily focused on health care and working with providers to improve the quality of care given to their patient panel. My path has been a blend of business and technology and I am excited to see how this certification can bring additional value to my work.*

# %% [markdown]
# ### The following will show 1+1= 2

# %%
1 + 1
# Out:
# 2

# %% [markdown]
# Bullet List <br>
# - Apple
# - Orange
# - Banana
#
# Now a Numbered List
# 1. Apple
# 2. Orange
# 3. Banana
#
# Image It's me!
#
#
# ![Me 05222022.jpg](attachment:2007a4ae-3515-45d0-8813-b06979c2417a.jpg)
